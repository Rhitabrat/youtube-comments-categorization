# %%
# importing the libraries

import pandas as pd
import re
from nltk.corpus import stopwords

# %%
# loading the data

df = pd.read_csv('Scrapper/final.csv', header=None)
df.rename(columns={0: 'comment', 1: 'category'}, inplace=True)

# %%
df.category.unique()
# Out:
# array(['positive', 'imperative', 'interrogative', 'other', 'correction',
#        'negative'], dtype=object)

# %%
df['category_id'] = df['category'].factorize()[0]
df.head()
# Out:
#                                              comment       category  \
# 0                                     Love you sir!!       positive
# 1  Please make videos on..Midpoint circle drawing...     imperative
# 2  I bought both of your courses on Udemy. You ar...  interrogative
# 3  Thank you very much, u really got me in the fi...       positive
# 4  i hope u are ok with everything going on again...          other
#
#    category_id
# 0            0
# 1            1
# 2            2
# 3            0
# 4            3

# %%
df.isnull().sum()
# Out:
# comment        0
# category       0
# category_id    0
# dtype: int64

# %%
df.shape
# Out:
# (1201, 3)

# %%
# preprocessing

# lowercasing
df['comment'] = df['comment'].str.lower()

# removing urls
df['comment'] = df['comment'].str.replace('http\S+|www.\S+', '', case=False)

# removing new lines "\n"
df['comment'] = df['comment'].replace('\n','', regex=True)

# removing all the punctuations
df["comment"] = df['comment'].str.replace('[^\w\s]',' ')

# removing integers
df['comment'] = df['comment'].replace('\d','', regex=True)

# removing emojis
df['comment'] = df['comment'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)
df
# Out:
#                                                 comment       category  \
# 0                                        love you sir         positive
# 1     please make videos on  midpoint circle drawing...     imperative
# 2     i bought both of your courses on udemy  you ar...  interrogative
# 3     thank you very much  u really got me in the fi...       positive
# 4     i hope u are ok with everything going on again...          other
# ...                                                 ...            ...
# 1196       what is the purpose of writing main function  interrogative
# 1197                  your teaching skill is awesome          positive
# 1198  we can use online compiler to run a program  t...  interrogative
# 1199  c programs can be compiled in browser and that...  interrogative
# 1200  sir i am about to persue cs engineering  will ...  interrogative
#
#       category_id
# 0               0
# 1               1
# 2               2
# 3               0
# 4               3
# ...           ...
# 1196            2
# 1197            0
# 1198            2
# 1199            2
# 1200            2
#
# [1201 rows x 3 columns]

# %%
# stemming
import nltk

stemmer = nltk.stem.SnowballStemmer('english')
def stem_text(text):
    return stemmer.stem(text)

df['comment'] = df['comment'].apply(stem_text)


# lemmatizing
lemmatizer = nltk.stem.WordNetLemmatizer()
def lemmatize_text(text):
    return lemmatizer.lemmatize(text)

df['comment'] = df['comment'].apply(lemmatize_text)
df
# Out:
#                                                 comment       category  \
# 0                                        love you sir         positive
# 1     please make videos on  midpoint circle drawing...     imperative
# 2     i bought both of your courses on udemy  you ar...  interrogative
# 3     thank you very much  u really got me in the fi...       positive
# 4     i hope u are ok with everything going on again...          other
# ...                                                 ...            ...
# 1196          what is the purpose of writing main funct  interrogative
# 1197                  your teaching skill is awesome          positive
# 1198  we can use online compiler to run a program  t...  interrogative
# 1199  c programs can be compiled in browser and that...  interrogative
# 1200  sir i am about to persue cs engineering  will ...  interrogative
#
#       category_id
# 0               0
# 1               1
# 2               2
# 3               0
# 4               3
# ...           ...
# 1196            2
# 1197            0
# 1198            2
# 1199            2
# 1200            2
#
# [1201 rows x 3 columns]

# %%
# removing stopwords
stop = stopwords.words('english')

df['comment'] = df['comment'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df
# Out:
#                                                 comment       category  \
# 0                                              love sir       positive
# 1     please make videos midpoint circle drawing bre...     imperative
# 2     bought courses udemy talented teacher keep pro...  interrogative
# 3     thank much u really got first video algorithm ...       positive
# 4              hope u ok everything going muslims indea          other
# ...                                                 ...            ...
# 1196                         purpose writing main funct  interrogative
# 1197                             teaching skill awesome       positive
# 1198  use online compiler run program became standal...  interrogative
# 1199  c programs compiled browser need installation ...  interrogative
# 1200      sir persue cs engineering benefitted lectures  interrogative
#
#       category_id
# 0               0
# 1               1
# 2               2
# 3               0
# 4               3
# ...           ...
# 1196            2
# 1197            0
# 1198            2
# 1199            2
# 1200            2
#
# [1201 rows x 3 columns]

# %%
# feature selection

def features(text):

    wordlist = wordstring.split()
    wordfreq = []
    
    for w in wordlist:
        c = wordlist.count(w)/len(wordlist)
        wordfreq.append(c)

    return wordfreq

wordstring = 'please make videos midpoint circle drawing please'
features(wordstring)
# Out:
# [0.2857142857142857,
#  0.14285714285714285,
#  0.14285714285714285,
#  0.14285714285714285,
#  0.14285714285714285,
#  0.14285714285714285,
#  0.2857142857142857]
